# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
data = pd.read_feather("./results/single-epsilon.feather")

sns.lineplot(
    x="x",
    y="coverage_coverage",
    hue="Hydra/params.epsilon",
    data=data
)
plt.show()

sns.lineplot(
    x="x",
    y="bound_agents_bound_agents",
    hue="Hydra/params.epsilon",
    data=data
)
plt.show()

# %%
data = pd.read_feather("./results/single-agents.feather")

sns.lineplot(
    x="x",
    y="coverage_coverage",
    hue="Hydra/init.platelets.nest.platelets",
    data=data
)
plt.show()

sns.lineplot(
    x="x",
    y="bound_agents_bound_agents",
    hue="Hydra/init.platelets.nest.platelets",
    data=data
)
plt.show()

# %%
data = pd.read_feather("./results/single-dimension.feather")

data["ntb_agents"] = data["Hydra/scenario.ntb"] + "_" + data["Hydra/init.platelets.nest.platelets"]

sns.lineplot(
    x="x",
    y="coverage_coverage",
    hue="ntb_agents",
    data=data
)
plt.show()

sns.lineplot(
    x="x",
    y="bound_agents_bound_agents",
    hue="ntb_agents",
    data=data
)
plt.show()

# %%
data = pd.read_feather("./results/single-nests.feather")

data["nests_agents"] = data["Hydra/init.platelets.nests"] + "_" + data["Hydra/init.platelets.nest.platelets"]

sns.lineplot(
    x="x",
    y="coverage_coverage",
    hue="nests_agents",
    data=data
)
plt.show()

sns.lineplot(
    x="x",
    y="bound_agents_bound_agents",
    hue="nests_agents",
    data=data
)
plt.show()

# %%
data = pd.read_feather("./results/single-rab.feather")

data["dist_angle"] = data["Hydra/params.errors.rab_dist_more"] + "_" + data["Hydra/params.errors.rab_angle"]

sns.lineplot(
    x="x",
    y="coverage_coverage",
    hue="dist_angle",
    data=data
)
plt.show()

sns.lineplot(
    x="x",
    y="bound_agents_bound_agents",
    hue="dist_angle",
    data=data
)
plt.show()

# %%
data = pd.read_feather("./results/single-pfault.feather")

data["dist_angle"] = data["Hydra/params.errors.rab_dist_more"] + "_" + data["Hydra/params.errors.rab_angle"]

sns.lineplot(
    x="x",
    y="coverage_coverage",
    hue="dist_angle",
    data=data
)
plt.show()

sns.lineplot(
    x="x",
    y="bound_agents_bound_agents",
    hue="dist_angle",
    data=data
)
plt.show()
